# %% [markdown]
# # Simple linear Regression

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
model=LinearRegression()

# %%
x=df[['petal_width']]
y=df['sepal_width']
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[0.2]])
# Out:
# C:\Users\Qadri\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.26655359])

# %%
#print the slope and intercept
print("Intercept is:",model.intercept_)
print("slope is:",model.coef_)
# Out:
# Intercept is: 3.3084255580651947
# slope is: [-0.20935983]

# %%
plt.scatter(x,y)

# %%
y_pred= model.predict(x)

# %%
plt.plot(x,y_pred,color='red')

# %%
plt.plot(x,y,color="red")

# %%
plt.plot(x,y_pred,color='red')
plt.plot(x,y,color="blue")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.8)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
plt.plot(x_test,y_pred,color='red')
plt.scatter(x_test,y_test,color="blue")
plt.plot(x,y,color="green")

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
print("R2 score is:",r2_score(y_test,y_pred))
print("mean squared error is:",mean_squared_error(y_test,y_pred))
print("mean absolute error is:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score is: 0.27080023666995023
# mean squared error is: 0.1073057962838131
# mean absolute error is: 0.26897156290715457
